# %% [markdown]
# # **Author: Mohd Masood Raza**

# %% [markdown]
# ### Import required libraries

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import graphviz
from IPython.display import Image

# %% [markdown]
# ### Load the iris dataset

# %%
df = pd.read_csv("Iris.csv")

# %% [markdown]
# ### Check first few row of dataset

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# ### drop Id column

# %%
df.drop('Id',axis=1,inplace=True)

# %% [markdown]
# ### Step 2: Separate the features and target variable.

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %% [markdown]
# ### Split the data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Create the decision tree classifier

# %%
classifier = DecisionTreeClassifier()

# %% [markdown]
# ### Train the classifier on the training set

# %%
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Predict the target variable for the test data.

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# ### Calculate the accuracy of the classifier

# %%
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 1.0

# %% [markdown]
# ### Visualize the tree graphically using the Graphviz library

# %%
dot_data = export_graphviz(classifier, out_file=None, feature_names=X.columns, class_names=y.unique(), filled=True, rounded=True, special_characters=True)
graph = graphviz.Source(dot_data)
graph.format = 'png'
graph.render('iris_decision_tree', view=True)

Image(filename='iris_decision_tree.png')
